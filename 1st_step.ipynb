# %% [markdown]
# <a href="https://colab.research.google.com/github/ZebraHead22/PolyPhotonics2021/blob/main/1st_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ZebraHead22/PolyPhotonics2021.git
# Out:
# Cloning into 'PolyPhotonics2021'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
import imutils
import cv2
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('PolyPhotonics2021/tetris_blocks.png')
print("Image color")
cv2_imshow(image)
# convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print("Image gray")
cv2_imshow(gray)
# Out:
# Image color
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F1F53B519D0>
# Image gray
# <PIL.Image.Image image mode=L size=482x250 at 0x7F1F53AEBC10>

# %%
edged = cv2.Canny(gray, 30, 150)
print("Image edged")
cv2_imshow(edged)
# Out:
# Image edged
# <PIL.Image.Image image mode=L size=482x250 at 0x7F1F53A7D1D0>

# %%
thresh = cv2.threshold(gray, 225, 255, cv2.THRESH_BINARY_INV)[1]
print("Image thresh")
cv2_imshow(thresh)
import numpy as np
print(np.max(thresh))
# Out:
# Image thresh
# <PIL.Image.Image image mode=L size=482x250 at 0x7F1F53A86210>
# 255

# %%
# find contours (i.e., outlines) of the foreground objects in the
# thresholded image
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
output = image.copy()
# loop over the contours
print("Contours")
for c in cnts:
	# draw each contour on the output image with a 3px thick red
	# outline, then display the output contours one at a time
	cv2.drawContours(output, [c], -1, (0, 0, 0), 3)
text = "Found {} objects!".format(len(cnts))
print(text)
cv2_imshow(output)
# Out:
# Contours
# Found 6 objects!
# <PIL.Image.Image image mode=RGB size=482x250 at 0x7F1F53AEBE90>
